# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('pokemon.csv')

# %% [markdown]
# EDA

# %%
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df.dtypes
# Out:
# abilities             object
# against_bug          float64
# against_dark         float64
# against_dragon       float64
# against_electric     float64
# against_fairy        float64
# against_fight        float64
# against_fire         float64
# against_flying       float64
# against_ghost        float64
# against_grass        float64
# against_ground       float64
# against_ice          float64
# against_normal       float64
# against_poison       float64
# against_psychic      float64
# against_rock         float64
# against_steel        float64
# against_water        float64
# attack                 int64
# base_egg_steps         int64
# base_happiness         int64
# base_total             int64
# capture_rate          object
# classfication         object
# defense                int64
# experience_growth      int64
# height_m             float64
# hp                     int64
# japanese_name         object
# name                  object
# percentage_male      float64
# ...

# %%
df.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# ...

# %%
df.describe(include='object')
# Out:
#            abilities capture_rate   classfication japanese_name      name  \
# count            801          801             801           801       801
# unique           482           34             588           801       801
# top     ['Levitate']           45  Dragon Pokémon  Magearnaマギアナ  Magearna
# freq              29          250               8             1         1
#
#         type1   type2
# count     801     417
# unique     18      18
# top     water  flying
# freq      114      95

# %% [markdown]
# 1. O que você entendeu aqui ?

# %%
df['capture_rate'].unique()
# Out:
# array(['45', '255', '120', '127', '90', '190', '75', '235', '150', '25',
#        '170', '50', '200', '100', '180', '60', '225', '30', '35', '3',
#        '65', '70', '125', '205', '155', '145', '130', '140', '15', '220',
#        '160', '80', '55', '30 (Meteorite)255 (Core)'], dtype=object)

# %%
df['type1'].unique()
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %%
df['type1'].value_counts().idxmin()
# Out:
# 'flying'

# %%
df['type1'].value_counts()
# Out:
# type1
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# poison       32
# ground       32
# dark         29
# fighting     28
# dragon       27
# ghost        27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: count, dtype: int64

# %%
df['type2'].value_counts()
# Out:
# type2
# flying      95
# poison      34
# ground      34
# fairy       29
# psychic     29
# fighting    25
# steel       22
# dark        21
# grass       20
# water       17
# dragon      17
# ice         15
# ghost       14
# rock        14
# fire        13
# electric     9
# bug          5
# normal       4
# Name: count, dtype: int64

# %% [markdown]
# 3. Qual o type mais raro juntando type1 e type2?

# %%
df['combined_types'] = df['type1'] + " / " + df['type2']

# %%
df['combined_types'].value_counts().idxmin()
# Out:
# 'electric / electric'

# %%
frequencias = df['combined_types'].value_counts()

# %%
frequencias[frequencias == frequencias.min()]
# Out:
# combined_types
# electric / electric    1
# ghost / dark           1
# grass / ground         1
# water / steel          1
# normal / water         1
# psychic / grass        1
# ground / fire          1
# steel / ground         1
# fire / rock            1
# rock / dark            1
# dark / ghost           1
# bug / ground           1
# bug / ghost            1
# dragon / ice           1
# dragon / electric      1
# dragon / fire          1
# rock / fighting        1
# steel / fighting       1
# ground / electric      1
# poison / bug           1
# fighting / steel       1
# steel / dragon         1
# electric / ghost       1
# fire / steel           1
# ghost / dragon         1
# psychic / fire         1
# grass / grass          1
# ground / steel         1
# fire / fire            1
# ice / ghost            1
# psychic / fighting     1
# fighting / flying      1
# poison / dragon        1
# fighting / dark        1
# normal / ground        1
# fire / psychic         1
# ...

# %%
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  pokedex_number  sp_attack  sp_defense  \
# ...

# %% [markdown]
# 4. Escolha uma variavel que queira explorar visualmente e faça um gráfico.

# %%
fig = px.box(df['weight_kg'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df['weight_kg'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary', 'combined_types'],
#       dtype='object')

# %%
columns_to_keep = ['against_bug', 'against_dark', 'against_dragon',
       'against_electric', 'against_fairy', 'against_fight', 'against_fire',
       'against_flying', 'against_ghost', 'against_grass', 'against_ground',
       'against_ice', 'against_normal', 'against_poison', 'against_psychic',
       'against_rock', 'against_steel', 'against_water']
df_selected = df[columns_to_keep]

# %%
df_selected.corr()
# Out:
#                   against_bug  against_dark  against_dragon  against_electric  \
# against_bug          1.000000      0.230107        0.165430         -0.246943
# against_dark         0.230107      1.000000        0.140830         -0.015830
# against_dragon       0.165430      0.140830        1.000000         -0.108928
# against_electric    -0.246943     -0.015830       -0.108928          1.000000
# against_fairy        0.239566     -0.301354        0.439705         -0.089864
# against_fight        0.137902     -0.357981        0.035237         -0.102798
# against_fire         0.202778      0.010527       -0.261570         -0.279029
# against_flying       0.183343     -0.179697        0.064850         -0.111461
# against_ghost        0.129174      0.672337       -0.049941         -0.073031
# against_grass        0.079197     -0.006533       -0.037135          0.056209
# against_ground      -0.186841     -0.007660       -0.120042         -0.269444
# ...

# %%
fig = px.imshow(df_selected.corr())
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 5. Analise a relação de 2 colunas do DataSet com um gráfico

# %%
fig = px.scatter(df, x='attack', y='defense', title="Atck x Def", trendline="ols")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
