# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('BRAZIL_CITIES.csv', delimiter=';')

# %%
df.head()
# Out:
#                   CITY STATE  CAPITAL  IBGE_RES_POP  IBGE_RES_POP_BRAS  \
# 0      Abadia De Goiás    GO        0       6876.00            6876.00
# 1  Abadia Dos Dourados    MG        0       6704.00            6704.00
# 2            Abadiânia    GO        0      15757.00           15609.00
# 3               Abaeté    MG        0      22690.00           22690.00
# 4           Abaetetuba    PA        0     141100.00          141040.00
#
#    IBGE_RES_POP_ESTR  IBGE_DU  IBGE_DU_URBAN  IBGE_DU_RURAL  IBGE_POP  ...  \
# 0               0.00  2137.00        1546.00         591.00   5300.00  ...
# 1               0.00  2328.00        1481.00         847.00   4154.00  ...
# 2             148.00  4655.00        3233.00        1422.00  10656.00  ...
# 3               0.00  7694.00        6667.00        1027.00  18464.00  ...
# 4              60.00 31061.00       19057.00       12004.00  82956.00  ...
#
#    Pu_Bank   Pr_Assets    Pu_Assets    Cars  Motorcycles  Wheeled_tractor  \
# ...

# %% [markdown]
# ## DATA UNDERSTAND - EDA: Analise Exploratoria de Dados

# %% [markdown]
# 1. Descrever os tipos de dados das colunas
# 2. Descrever máximo, mínimo e média das variáveis numéricas

# %%
df.dtypes
# Out:
# CITY                  object
# STATE                 object
# CAPITAL                int64
# IBGE_RES_POP         float64
# IBGE_RES_POP_BRAS    float64
#                       ...
# Wheeled_tractor      float64
# UBER                 float64
# MAC                  float64
# WAL-MART             float64
# POST_OFFICES         float64
# Length: 81, dtype: object

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
df.describe()
# Out:
#        CAPITAL  IBGE_RES_POP  IBGE_RES_POP_BRAS  IBGE_RES_POP_ESTR    IBGE_DU  \
# count  5573.00       5565.00            5565.00            5565.00    5563.00
# mean      0.00      34277.77           34200.27              77.50   10302.72
# std       0.07     203112.62          201490.49            1795.88   64776.71
# min       0.00        805.00             805.00               0.00     239.00
# 25%       0.00       5235.00            5230.00               0.00    1572.50
# 50%       0.00      10934.00           10926.00               0.00    3174.00
# 75%       0.00      23424.00           23390.00              10.00    6726.00
# max       1.00   11253503.00        11133776.00          119727.00 3576148.00
#
#        IBGE_DU_URBAN  IBGE_DU_RURAL    IBGE_POP    IBGE_1  IBGE_1-4  ...  \
# count        5563.00        5492.00     5565.00   5565.00   5565.00  ...
# mean         8858.76        1462.64    27594.66    383.28   1544.53  ...
# ...

# %%
df.describe(include='object')
# Out:
#                 CITY STATE    AREA            REGIAO_TUR CATEGORIA_TUR  \
# count           5573  5573    5570                  3285          3285
# unique          5299    27    5444                   322             5
# top     São Domingos    MG  196.57  Corredores Das Águas             D
# freq               5   853       2                    59          1892
#
#             RURAL_URBAN                                           GVA_MAIN
# count              5570                                               5570
# unique                6                                                 10
# top     Rural Adjacente  Administração, defesa, educação e saúde públic...
# freq               3040                                               2725

# %% [markdown]
# 3. Fazer um BoxPlot ou Histograma de uma variável numérica

# %%
sns.histplot(data=df, x='IBGE_DU_RURAL')
# Out:
# <Axes: xlabel='IBGE_DU_RURAL', ylabel='Count'>

# %%
sns.boxplot(data=df, x='IBGE_DU_RURAL')
# Out:
# <Axes: xlabel='IBGE_DU_RURAL'>

# %%
df['AREA'][0]
# Out:
# '147.26'

# %%
type(df['AREA'][0])
# Out:
# str

# %% [markdown]
# 4. Descobrir se tem dados Nulos ou faltantes em alguma coluna

# %%
df.isnull().sum()
# Out:
# CITY                    0
# STATE                   0
# CAPITAL                 0
# IBGE_RES_POP            8
# IBGE_RES_POP_BRAS       8
#                      ...
# Wheeled_tractor        11
# UBER                 5448
# MAC                  5407
# WAL-MART             5471
# POST_OFFICES          120
# Length: 81, dtype: int64

# %%
df.shape
# Out:
# (5573, 81)
